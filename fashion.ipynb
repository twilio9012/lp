# %%
import matplotlib.pyplot as plt
import pandas as pd

# %%
train_df = pd.read_csv('fashion_train.csv')
test_df = pd.read_csv('fashion_test.csv')

# %%
train_df.shape
# Out:
# (60000, 785)

# %%
test_df.shape
# Out:
# (10000, 785)

# %%
train_df.describe()
# Out:
#               label        pixel1        pixel2        pixel3        pixel4  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       4.500000      0.000900      0.006150      0.035333      0.101933
# std        2.872305      0.094689      0.271011      1.222324      2.452871
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        2.000000      0.000000      0.000000      0.000000      0.000000
# 50%        4.500000      0.000000      0.000000      0.000000      0.000000
# 75%        7.000000      0.000000      0.000000      0.000000      0.000000
# max        9.000000     16.000000     36.000000    226.000000    164.000000
#
#              pixel5        pixel6        pixel7        pixel8        pixel9  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean       0.247967      0.411467      0.805767      2.198283      5.682000
# std        4.306912      5.836188      8.215169     14.093378     23.819481
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      227.000000    230.000000    224.000000    255.000000    254.000000
#
#        ...      pixel775      pixel776      pixel777      pixel778  \
# count  ...  60000.000000  60000.000000  60000.000000  60000.000000
# mean   ...     34.625400     23.300683     16.588267     17.869433
# std    ...     57.545242     48.854427     41.979611     43.966032
# min    ...      0.000000      0.000000      0.000000      0.000000
# 25%    ...      0.000000      0.000000      0.000000      0.000000
# 50%    ...      0.000000      0.000000      0.000000      0.000000
# 75%    ...     58.000000      9.000000      0.000000      0.000000
# max    ...    255.000000    255.000000    255.000000    255.000000
#
#            pixel779      pixel780      pixel781      pixel782      pixel783  \
# count  60000.000000  60000.000000  60000.000000  60000.000000  60000.000000
# mean      22.814817     17.911483      8.520633      2.753300      0.855517
# std       51.830477     45.149388     29.614859     17.397652      9.356960
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000      0.000000
# 50%        0.000000      0.000000      0.000000      0.000000      0.000000
# 75%        0.000000      0.000000      0.000000      0.000000      0.000000
# max      255.000000    255.000000    255.000000    255.000000    255.000000
#
#           pixel784
# count  60000.00000
# mean       0.07025
# std        2.12587
# min        0.00000
# 25%        0.00000
# 50%        0.00000
# 75%        0.00000
# max      170.00000
#
# [8 rows x 785 columns]

# %%
train_df.label.unique()
# Out:
# array([2, 9, 6, 0, 3, 4, 5, 8, 7, 1])

# %%
class_names = ['T-shirt/top', 'Trouser', 'Pullover', 'Dress', 'Coat','Sandal', 'Shirt', 'Sneaker', 'Bag', 'Ankle boot']

# %%
x_train = train_df.iloc[:,1:].to_numpy()
x_train = x_train.reshape([-1,28,28,1])
x_train = x_train / 255

# %%
y_train = train_df.iloc[:,0].to_numpy()

# %%
x_test = test_df.iloc[:,1:].to_numpy()
x_test = x_test.reshape([-1,28,28,1])
x_test = x_test / 255

# %%
y_test = test_df.iloc[:,0].to_numpy()

# %%
plt.figure(figsize=(10,10))
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_train[i], cmap=plt.cm.binary)
    plt.xlabel(class_names[y_train[i]])
plt.show()

# %%
from keras.models import Sequential
from keras.layers import Dense,Conv2D,Flatten,MaxPooling2D,Dropout

# %%
model = Sequential()

model.add(Conv2D(filters=64,kernel_size=(3,3),input_shape=(28,28,1),activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2)))
model.add(Dropout(rate=0.3))
model.add(Flatten())
model.add(Dense(units=32, activation='relu'))
model.add(Dense(units=10, activation='sigmoid'))
model.compile(loss='sparse_categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
model.summary()
# Out:
# C:\Users\vaish\AppData\Roaming\Python\Python310\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ conv2d (Conv2D)                      │ (None, 26, 26, 64)          │             640 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dropout (Dropout)                    │ (None, 13, 13, 64)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (None, 10816)               │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (None, 32)                  │         346,144 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 10)                  │             330 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 347,114 (1.32 MB)
#  Trainable params: 347,114 (1.32 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.fit(x_train,y_train,epochs=50,batch_size=1200,validation_split=0.05)
# Out:
# Epoch 1/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 13s 208ms/step - accuracy: 0.5685 - loss: 1.3088 - val_accuracy: 0.8033 - val_loss: 0.5430
# Epoch 2/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.8261 - loss: 0.4965 - val_accuracy: 0.8403 - val_loss: 0.4547
# Epoch 3/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 206ms/step - accuracy: 0.8511 - loss: 0.4250 - val_accuracy: 0.8540 - val_loss: 0.4092
# Epoch 4/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 11s 218ms/step - accuracy: 0.8689 - loss: 0.3782 - val_accuracy: 0.8693 - val_loss: 0.3731
# Epoch 5/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 208ms/step - accuracy: 0.8761 - loss: 0.3588 - val_accuracy: 0.8813 - val_loss: 0.3481
# Epoch 6/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 209ms/step - accuracy: 0.8844 - loss: 0.3294 - val_accuracy: 0.8810 - val_loss: 0.3381
# Epoch 7/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 211ms/step - accuracy: 0.8907 - loss: 0.3155 - val_accuracy: 0.8793 - val_loss: 0.3359
# Epoch 8/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s 204ms/step - accuracy: 0.8911 - loss: 0.3098 - val_accuracy: 0.8923 - val_loss: 0.3131
# Epoch 9/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 10s
50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 16s 326ms/step - accuracy: 0.9331 - loss: 0.1889 - val_accuracy: 0.9150 - val_loss: 0.2424
# Epoch 36/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 391ms/step - accuracy: 0.9333 - loss: 0.1852 - val_accuracy: 0.9160 - val_loss: 0.2416
# Epoch 37/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 401ms/step - accuracy: 0.9354 - loss: 0.1808 - val_accuracy: 0.9143 - val_loss: 0.2446
# Epoch 38/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 389ms/step - accuracy: 0.9354 - loss: 0.1783 - val_accuracy: 0.9157 - val_loss: 0.2453
# Epoch 39/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 372ms/step - accuracy: 0.9351 - loss: 0.1811 - val_accuracy: 0.9137 - val_loss: 0.2466
# Epoch 40/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 384ms/step - accuracy: 0.9346 - loss: 0.1809 - val_accuracy: 0.9143 - val_loss: 0.2430
# Epoch 41/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 391ms/step - accuracy: 0.9364 - loss: 0.1802 - val_accuracy: 0.9160 - val_loss: 0.2388
# Epoch 42/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 18s 367ms/step - accuracy: 0.9387 - loss: 0.1671 - val_accuracy: 0.9143 - val_loss: 0.2370
# Epoch 43/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 393ms/step - accuracy: 0.9390 - loss: 0.1709 - val_accuracy: 0.9163 - val_loss: 0.2385
# Epoch 44/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 396ms/step - accuracy: 0.9389 - loss: 0.1699 - val_accuracy: 0.9140 - val_loss: 0.2419
# Epoch 45/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 414ms/step - accuracy: 0.9399 - loss: 0.1684 - val_accuracy: 0.9173 - val_loss: 0.2388
# Epoch 46/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 408ms/step - accuracy: 0.9412 - loss: 0.1613 - val_accuracy: 0.9177 - val_loss: 0.2386
# Epoch 47/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 19s 390ms/step - accuracy: 0.9427 - loss: 0.1562 - val_accuracy: 0.9147 - val_loss: 0.2403
# Epoch 48/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 422ms/step - accuracy: 0.9425 - loss: 0.1578 - val_accuracy: 0.9140 - val_loss: 0.2363
# Epoch 49/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 21s 425ms/step - accuracy: 0.9446 - loss: 0.1569 - val_accuracy: 0.9133 - val_loss: 0.2461
# Epoch 50/50
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 20s 409ms/step - accuracy: 0.9411 - loss: 0.1623 - val_accuracy: 0.9160 - val_loss: 0.2389

# %%
evaluation = model.evaluate(x_test,y_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 16ms/step - accuracy: 0.9171 - loss: 0.2325

# %%
print(f"Accuracy: {evaluation[1]}")
# Out:
# Accuracy: 0.9207000136375427

# %%
y_probas = model.predict(x_test)
# Out:
# 313/313 ━━━━━━━━━━━━━━━━━━━━ 5s 15ms/step

# %%
y_pred = y_probas.argmax(axis=-1)

# %%
y_pred
# Out:
# array([0, 1, 2, ..., 8, 8, 1])

# %%
plt.figure(figsize=(10,10),)
for i in range(25):
    plt.subplot(5,5,i+1)
    plt.xticks([])
    plt.yticks([])
    plt.grid(False)
    plt.imshow(x_test[i], cmap=plt.cm.binary)
#     plt.xlabel(f"True Class:{y_test[i]}")
    plt.title(f"Pred:{class_names[y_pred[i]]}")
plt.show()

# %%
from sklearn.metrics import classification_report

# %%
num_classes = 10
class_names = ["class {}".format(i) for i in range(num_classes)]
cr = classification_report(y_test, y_pred, target_names=class_names)
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#      class 0       0.84      0.92      0.88      1000
#      class 1       0.99      0.99      0.99      1000
#      class 2       0.92      0.82      0.87      1000
#      class 3       0.92      0.95      0.93      1000
#      class 4       0.87      0.91      0.89      1000
#      class 5       0.99      0.97      0.98      1000
#      class 6       0.80      0.75      0.77      1000
#      class 7       0.97      0.94      0.96      1000
#      class 8       0.98      0.98      0.98      1000
#      class 9       0.94      0.98      0.96      1000
#
#     accuracy                           0.92     10000
#    macro avg       0.92      0.92      0.92     10000
# weighted avg       0.92      0.92      0.92     10000
